# %% [markdown]
# <a href="https://colab.research.google.com/github/sergiomar73/nlp-google-colab/blob/main/nlp_poc_01_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pickle5
#   Downloading pickle5-0.0.12-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (256 kB)
#      |████████████████████████████████| 256 kB 4.1 MB/s
# Installing collected packages: pickle5
# Successfully installed pickle5-0.0.12

# %%
import numpy as np
import pandas as pd
import pickle5 as pickle

# %%
df_phrases_path = './df_phrases.pkl'
df_phrases = pd.read_pickle(df_phrases_path)
print(df_phrases.shape)
df_phrases.head(3)
# Out:
# (64, 4)
#              category label  \
# 0  What is Quantified  What
# 1  What is Quantified  What
# 2  What is Quantified  What
#
#                                              example  \
# 0  most advanced conversation intelligence and AI...
# 1  a software platform that helps people reach th...
# 2                   for communicating and connecting
#
#                                            embedding
# 0  [-0.007960937917232513, 0.0075285546481609344,...
# 1  [-0.00591889675706625, 2.6476920538698323e-05,...
# 2  [-0.005206338595598936, 0.0007997832144610584,...

# %%
df_sentences_path = './df_sentences.pkl'
df_sentences = pd.read_pickle(df_sentences_path)
print(df_sentences.shape)
df_sentences.head(3)
# Out:
# (145, 4)
#                                      id line  \
# 0  1d43516c-dbbd-4446-bce4-f9b6f7a24c17    1
# 1  1d43516c-dbbd-4446-bce4-f9b6f7a24c17    2
# 2  1d43516c-dbbd-4446-bce4-f9b6f7a24c17    3
#
#                                             sentence  \
# 0                    Hello, how are you doing today?
# 1  I'm here to tell you a little bit about, uh, q...
# 2  So I'll get started off by telling you just a ...
#
#                                            embedding
# 0  [-0.003950469195842743, 0.015000976622104645, ...
# 1  [-0.009600087068974972, 0.002050349721685052, ...
# 2  [-0.009551599621772766, 0.0032257316634058952,...

# %%
targets = np.array([ np.array(value[0]) for value in df_phrases[["embedding"]].values ])

print(f"targets:{targets.shape}")
# Out:
# targets:(64, 12288)

# %%
source = np.array(df_phrases.at[44, 'embedding'])

cosine = np.dot(targets,source)/(np.linalg.norm(targets, axis=1)*np.linalg.norm(source))
print("Cosine Similarity:\n", cosine)
# Out:
# Cosine Similarity:
#  [0.63291905 0.71119643 0.76600344 0.75838243 0.74709506 0.6841239
#  0.74884234 0.72057541 0.68272436 0.72409076 0.73043986 0.70272559
#  0.71142111 0.70055694 0.75481309 0.71362931 0.80423701 0.80402681
#  0.77673815 0.77777488 0.78883116 0.76859927 0.74407837 0.7324718
#  0.76340525 0.70304523 0.65241871 0.74636144 0.73697883 0.79221179
#  0.72403717 0.71342757 0.67599985 0.65503028 0.68514939 0.68376029
#  0.70828598 0.77416911 0.68672298 0.69293376 0.69466169 0.65849629
#  0.80533878 0.78029426 1.         0.83089543 0.77405214 0.75014906
#  0.71469734 0.72415817 0.73380653 0.64737821 0.7853971  0.72692577
#  0.70100115 0.74472761 0.64986644 0.70312394 0.73223021 0.71782126
#  0.74252323 0.71580584 0.68306556 0.76366145]

# %%
source = np.array(df_phrases.at[45, 'embedding'])

cosine = np.dot(targets,source)/(np.linalg.norm(targets, axis=1)*np.linalg.norm(source))
print("Cosine Similarity:\n", cosine)
# Out:
# Cosine Similarity:
#  [0.68167521 0.71867767 0.85514195 0.72858584 0.72274773 0.7008403
#  0.72733545 0.71909424 0.72948085 0.68511418 0.70803147 0.65520734
#  0.73507779 0.69075684 0.7338934  0.71879783 0.70717346 0.72289735
#  0.68758453 0.71928776 0.71772456 0.71260493 0.73751113 0.73066028
#  0.71058241 0.70396313 0.72393609 0.72020632 0.72884403 0.8057099
#  0.67010964 0.71393412 0.70261173 0.6751754  0.7381613  0.71505573
#  0.71512079 0.72940563 0.71184324 0.69342766 0.69062695 0.67596789
#  0.74254463 0.81811895 0.83089543 1.         0.73481554 0.83284762
#  0.70509842 0.72507719 0.70132098 0.65402026 0.73449122 0.72513215
#  0.68221403 0.70905441 0.6883596  0.72385682 0.71572528 0.69799928
#  0.70980707 0.72229069 0.71366388 0.77221938]

# %%
df_cosines = pd.DataFrame(columns=['id', 'line'])

for i, row in df_sentences.iterrows():
    line = f'{row["line"]:03}'
    # print(f'Calculating cosines for [ { row["id"] } / { line } ] {row["sentence"][:50]}...')
    source = np.array(row["embedding"])
    cosine = np.dot(targets,source)/(np.linalg.norm(targets, axis=1)*np.linalg.norm(source))
    # print("Cosine Similarity:\n", cosine)
    # Create new row
    new_row = dict([(f"Cosine{f'{key:02}'}", value) for key, value in enumerate(cosine.flatten(), 1)])
    new_row["id"] = row["id"]
    new_row["line"] = row["line"]
    df_cosines = df_cosines.append(new_row, ignore_index=True)

df_cosines
# Out:
#                                        id line  Cosine01  Cosine02  Cosine03  \
# 0    1d43516c-dbbd-4446-bce4-f9b6f7a24c17    1  0.647840  0.685653  0.689358
# 1    1d43516c-dbbd-4446-bce4-f9b6f7a24c17    2  0.793354  0.746575  0.688302
# 2    1d43516c-dbbd-4446-bce4-f9b6f7a24c17    3  0.770353  0.757640  0.676912
# 3    1d43516c-dbbd-4446-bce4-f9b6f7a24c17    4  0.883998  0.765685  0.679948
# 4    1d43516c-dbbd-4446-bce4-f9b6f7a24c17    5  0.668047  0.706542  0.713122
# ..                                    ...  ...       ...       ...       ...
# 140  aea90db1-1d9b-4bc7-9946-88f6417b176b   42  0.634342  0.651318  0.659317
# 141  aea90db1-1d9b-4bc7-9946-88f6417b176b   43  0.714680  0.762122  0.705039
# 142  aea90db1-1d9b-4bc7-9946-88f6417b176b   44  0.653312  0.704783  0.697205
# 143  aea90db1-1d9b-4bc7-9946-88f6417b176b   45  0.700657  0.757256  0.709337
# 144  aea90db1-1d9b-4bc7-9946-88f6417b176b   46  0.745715  0.714433  0.632291
#
#      Cosine04  Cosine05  Cosine06  Cosine07  Cosine08  ...  Cosine55  \
# 0    0.724860  0.681512  0.672155  0.687316  0.688927  ...  0.646963
# 1    0.694458  0.672560  0.716549  0.663016  0.705523  ...  0.639954
# 2    0.702108  0.688316  0.687752  0.663500  0.713817  ...  0.670474
# 3    0.734298  0.741436  0.708583  0.654778  0.715267  ...  0.653852
# 4    0.730585  0.712739  0.667015  0.705764  0.723158  ...  0.715801
# ..        ...       ...       ...       ...       ...  ...       ...
# 140  0.696162  0.676782  0.621741  0.662360  0.677096  ...  0.698184
# 141  0.762588  0.689535  0.703864  0.710740  0.766093  ...  0.674443
# 142  0.728429  0.674525  0.677445  0.678581  0.711856  ...  0.691217
# 143  0.756366  0.694433  0.684174  0.701464  0.765956  ...  0.696222
# 144  0.682947  0.611372  0.648768  0.624782  0.681524  ...  0.589603
#
#      Cosine56  Cosine57  Cosine58  Cosine59  Cosine60  Cosine61  Cosine62  \
# 0    0.694437  0.646987  0.695505  0.703807  0.678319  0.711509  0.685593
# 1    0.657171  0.743381  0.686107  0.697144  0.661339  0.672070  0.721339
# 2    0.690668  0.722508  0.701332  0.716044  0.686732  0.689009  0.716929
# 3    0.687882  0.730898  0.705535  0.735733  0.694845  0.689099  0.726393
# 4    0.726750  0.666372  0.685545  0.739466  0.749744  0.715933  0.696455
# ..        ...       ...       ...       ...       ...       ...       ...
# 140  0.690029  0.659809  0.641703  0.718154  0.690318  0.668460  0.665280
# 141  0.768065  0.726104  0.719759  0.735752  0.734062  0.804471  0.714136
# 142  0.720610  0.687467  0.686606  0.722501  0.728750  0.743104  0.672327
# 143  0.755680  0.730666  0.722838  0.748047  0.734755  0.759823  0.704470
# 144  0.611093  0.685210  0.769242  0.697105  0.634328  0.637886  0.652686
#
#      Cosine63  Cosine64
# 0    0.682147  0.723876
# 1    0.705404  0.670754
# 2    0.714853  0.675136
# 3    0.710555  0.681107
# 4    0.708273  0.729882
# ..        ...       ...
# 140  0.676640  0.661796
# 141  0.760811  0.728320
# 142  0.717940  0.738292
# 143  0.752529  0.765280
# 144  0.677178  0.668035
#
# [145 rows x 66 columns]

# %%
print(df_sentences.shape)
print(df_cosines.shape)
df_comparison = pd.concat([df_sentences, df_cosines.loc[:, 'Cosine01':'Cosine64']], axis="columns")
print(df_comparison.shape)
df_comparison.head()
# Out:
# (145, 4)
# (145, 66)
# (145, 68)
#                                      id line  \
# 0  1d43516c-dbbd-4446-bce4-f9b6f7a24c17    1
# 1  1d43516c-dbbd-4446-bce4-f9b6f7a24c17    2
# 2  1d43516c-dbbd-4446-bce4-f9b6f7a24c17    3
# 3  1d43516c-dbbd-4446-bce4-f9b6f7a24c17    4
# 4  1d43516c-dbbd-4446-bce4-f9b6f7a24c17    5
#
#                                             sentence  \
# 0                    Hello, how are you doing today?
# 1  I'm here to tell you a little bit about, uh, q...
# 2  So I'll get started off by telling you just a ...
# 3  Oh, so the quantified platform is one of the m...
# 4                    And what does that really mean?
#
#                                            embedding  Cosine01  Cosine02  \
# 0  [-0.003950469195842743, 0.015000976622104645, ...  0.647840  0.685653
# 1  [-0.009600087068974972, 0.002050349721685052, ...  0.793354  0.746575
# 2  [-0.009551599621772766, 0.0032257316634058952,...  0.770353  0.757640
# 3  [-0.003871886758133769, 0.004901846870779991, ...  0.883998  0.765685
# 4  [-0.009942175820469856, 0.01378173753619194, -...  0.668047  0.706542
#
#    Cosine03  Cosine04  Cosine05  Cosine06  ...  Cosine55  Cosine56  Cosine57  \
# 0  0.689358  0.724860  0.681512  0.672155  ...  0.646963  0.694437  0.646987
# 1  0.688302  0.694458  0.672560  0.716549  ...  0.639954  0.657171  0.743381
# 2  0.676912  0.702108  0.688316  0.687752  ...  0.670474  0.690668  0.722508
# 3  0.679948  0.734298  0.741436  0.708583  ...  0.653852  0.687882  0.730898
# 4  0.713122  0.730585  0.712739  0.667015  ...  0.715801  0.726750  0.666372
#
#    Cosine58  Cosine59  Cosine60  Cosine61  Cosine62  Cosine63  Cosine64
# 0  0.695505  0.703807  0.678319  0.711509  0.685593  0.682147  0.723876
# 1  0.686107  0.697144  0.661339  0.672070  0.721339  0.705404  0.670754
# 2  0.701332  0.716044  0.686732  0.689009  0.716929  0.714853  0.675136
# 3  0.705535  0.735733  0.694845  0.689099  0.726393  0.710555  0.681107
# 4  0.685545  0.739466  0.749744  0.715933  0.696455  0.708273  0.729882
#
# [5 rows x 68 columns]
